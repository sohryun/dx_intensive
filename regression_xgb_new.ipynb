# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import explained_variance_score

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('./230216_RawDataSet.csv', index_col=0)
df.columns = ['inlet','outlet','g','w']
df['before'] = df['w'].shift(1)
df['before'].iloc[0] = df['w'].iloc[0]

# %%
use_col = ['inlet','outlet','before']

X_train, X_test, y_train, y_test = train_test_split(df.loc[:,use_col], df.loc[:,'w'], test_size=0.1,
                                                    random_state=42,shuffle=False)

# %%
y_test = y_test.tolist()
print("Training data shape:", X_train.shape)
print("Test data shape:", X_test.shape)
# Out:
# Training data shape: (459, 3)
# Test data shape: (52, 3)

# %%
# !pip install xgboost
# !pip install lightgbm
# Out:
# Collecting lightgbm
#   Downloading lightgbm-3.3.5-py3-none-win_amd64.whl (1.0 MB)
# Requirement already satisfied: numpy in d:\programdata\anaconda3\lib\site-packages (from lightgbm) (1.21.5)
# Requirement already satisfied: scikit-learn!=0.22.0 in d:\programdata\anaconda3\lib\site-packages (from lightgbm) (1.0.2)
# Requirement already satisfied: wheel in d:\programdata\anaconda3\lib\site-packages (from lightgbm) (0.37.1)
# Requirement already satisfied: scipy in d:\programdata\anaconda3\lib\site-packages (from lightgbm) (1.7.3)
# Requirement already satisfied: joblib>=0.11 in d:\programdata\anaconda3\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\programdata\anaconda3\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (2.2.0)
# Installing collected packages: lightgbm
# Successfully installed lightgbm-3.3.5

# %%
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %%
mean_absolute_error(X_test['before'],y_test)
mean_squared_error(X_test['before'],y_test)
# Out:
# 0.011267818400033729

# %% [markdown]
# * 이전 시점으로의 예측

# %%
plt.plot(X_test['before'].tolist())
plt.plot(y_test)

# %%
line_fitter = LinearRegression()
line_fitter.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_predicted = line_fitter.predict(X_test)

# %% [markdown]
# * Linear Regression 으로 예측

# %%
plt.plot(y_test)
plt.plot(y_predicted)

# %%
mean_absolute_error(y_predicted,y_test)
mean_squared_error(y_predicted,y_test)
# Out:
# 0.03006100559200932

# %% [markdown]
# # train fit 확인

# %%
y_predicted_train = line_fitter.predict(X_train)

plt.plot(y_train.tolist())
plt.plot(y_predicted_train)

# %% [markdown]
# ## XGB LGB 사용

# %%
xgb_model = XGBRegressor(n_estimators=100, learning_rate=0.08, gamma=0, subsample=0.75,
                           colsample_bytree=1, max_depth=5)
xgb_model.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=0, gpu_id=None,
#              grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.08, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
y_pred = xgb_model.predict(X_test)
y_pred_train = xgb_model.predict(X_train)

# %%
mean_absolute_error(y_pred,y_test)
mean_squared_error(y_pred,y_test)
# Out:
# 0.015156765163098817

# %%
plt.plot(y_train.tolist())
plt.plot(y_pred_train)

# %%
y_pred = xgb_model.predict(X_test)


plt.plot(y_test,label ='real')
plt.plot(y_pred,label ='pred')
plt.legend()
plt.show()

# %% [markdown]
# # Ligth GBM
#
# XGB       : 0.015156765163098817
# Light GBM : 0.012418695569071289

# %%
lgb_model = LGBMRegressor(n_estimators=100, learning_rate=0.08)
lgb_model.fit(X_train,y_train)
# Out:
# LGBMRegressor(learning_rate=0.08)

# %%
lgb_y_pred = lgb_model.predict(X_test)
lgb_y_pred_train = xgb_model.predict(X_train)

# %%
mean_absolute_error(lgb_y_pred,y_test)
mean_squared_error(lgb_y_pred,y_test)
# Out:
# 0.012418695569071289

# %%
plt.plot(y_train.tolist())
plt.plot(lgb_y_pred_train)

# %% [markdown]
# ## 대안
#
# * 다른 모델 사용
# * 데이터 noise 까지 학습되는 부분이 문제가 되는 것으로 확인 --> robust 모델 관점으로 접근
